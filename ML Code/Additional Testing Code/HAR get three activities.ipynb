# %%
import pandas as pd
import numpy as np
import math

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/HAR Dataset/HAR Mine")

# %%
# !ls "/content/drive/My Drive/HAR Dataset/HAR Mine"
# Out:
# 'Additional Testing Code'
# 'Basic Data'
#  checkpoint
#  converted_model.tflite
# 'data visualitaion.ipynb'
# 'Feature Test.ipynb'
#  frozen_har.pb
# 'HAR get three activities.ipynb'
#  history.p
#  human_activity_recognition_basic.ipynb
#  human_activity_recognition_Classifier.ipynb
# 'Human Activity Recognition Classifier Result.gsheet'
#  Human_activity_recognition_feature_extract.ipynb
#  Human_activity_recognition_magnitudeFeature_extract.ipynb
#  human_activity_recognition_MINE_2.ipynb
#  human_activity_recognition_MINE.ipynb
#  human_activity_recognition_with_raw_data.ipynb
#  predictions.p
# 'Processed Data'
# 'RNN Result.gsheet'
# 'Subject with number activities performed.gsheet'
#  wisdomDataRemoveJoggingActivity.ipynb

# %%
#df = pd.read_csv('Basic Data/accelerometer_data_merged_all_with_magnitude.csv')

df = pd.read_csv('Basic Data/accelerometer_data_merged_all.csv')

# %%
print(df.head())
# Out:
#           x          y         z  ...  subject_id               class timestamp_s
# 0 -0.304352   3.244934 -3.266479  ...           1  WALKING_DOWNSTAIRS  1563706375
# 1 -0.725739   4.875382 -2.603287  ...           1  WALKING_DOWNSTAIRS  1563706375
# 2 -5.396820   4.272049 -0.944107  ...           1  WALKING_DOWNSTAIRS  1563706375
# 3 -4.520538   2.160355 -2.248947  ...           1  WALKING_DOWNSTAIRS  1563706375
# 4 -7.034454  17.066650  2.139618  ...           1  WALKING_DOWNSTAIRS  1563706375
#
# [5 rows x 7 columns]

# %%
len(df)
# Out:
# 291997

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291997 entries, 0 to 291996
# Data columns (total 7 columns):
# x               291997 non-null float64
# y               291997 non-null float64
# z               291997 non-null float64
# timestamp_ms    291997 non-null float64
# subject_id      291997 non-null int64
# class           291997 non-null object
# timestamp_s     291997 non-null int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 15.6+ MB

# %%
np.unique(df['class'])
# Out:
# array(['SITTING', 'STANDING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)

# %%
new_df = df.loc[ df['class'] != 'WALKING_UPSTAIRS' ]

# %%
len(new_df)
# Out:
# 248380

# %%
new_df = new_df.loc[ df['class'] != 'WALKING_DOWNSTAIRS' ]

# %%
len(new_df)
# Out:
# 212577

# %%
np.unique(new_df['class'])
# Out:
# array(['SITTING', 'STANDING', 'WALKING'], dtype=object)

# %%
new_df.to_csv('Basic Data/Three_activities_data.csv', index=False)

# %%
len(new_df.loc[ df['class'] == 'WALKING' ])
# Out:
# 69862

# %%
len(new_df.loc[ df['class'] == 'SITTING' ])
# Out:
# 71397

# %%
len(new_df.loc[ df['class'] == 'STANDING' ])
# Out:
# 71318
